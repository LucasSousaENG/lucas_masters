# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasSousaENG/lucas_masters/blob/master/yolov3_lossmethod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab Notebook YOLOV3 Trainning based on Ultralytics method (https://github.com/ultralytics/yolov3)

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Mon Feb  3 22:10:59 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# Google Colab Notebook for Custom Training with Ultralytics YOLOv3

# Step 1: Clone the Ultralytics YOLOv3 Repository
# !git clone https://github.com/ultralytics/yolov3
# %cd yolov3
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 12088, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 12088 (delta 22), reused 15 (delta 15), pack-reused 12034 (from 3)
# Receiving objects: 100% (12088/12088), 10.65 MiB | 20.15 MiB/s, done.
# Resolving deltas: 100% (8199/8199), done.
# /content/yolov3

# %%
# Step 2: Install Dependencies
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 59.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 34.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 30.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# Step 3: Mount Google Drive and Extract Dataset
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Create necessary directories
# !mkdir /content/data
# !mkdir /content/data/obj

# %%
# Extract images into the training folder (change the path to your drive folder)
# Make sure the following folder or zip file has all the trainning images along with each corresponding image .txt detection file with the bouding boxes
# !unzip /content/gdrive/MyDrive/yolov3/Images.zip -d /content/data/obj
# Out:
# Archive:  /content/gdrive/MyDrive/yolov3/Images.zip
#   inflating: /content/data/obj/000.jpg
#   inflating: /content/data/obj/000.txt
#   inflating: /content/data/obj/001.jpg
#   inflating: /content/data/obj/001.txt
#   inflating: /content/data/obj/002.jpg
#   inflating: /content/data/obj/002.txt
#   inflating: /content/data/obj/003.jpg
#   inflating: /content/data/obj/003.txt
#   inflating: /content/data/obj/004.jpg
#   inflating: /content/data/obj/004.txt
#   inflating: /content/data/obj/005.jpg
#   inflating: /content/data/obj/005.txt
#   inflating: /content/data/obj/006.jpg
#   inflating: /content/data/obj/006.txt
#   inflating: /content/data/obj/007.jpg
#   inflating: /content/data/obj/007.txt
#   inflating: /content/data/obj/008.jpg
#   inflating: /content/data/obj/008.txt
#   inflating: /content/data/obj/009.jpg
#   inflating: /content/data/obj/009.txt
#   inflating: /content/data/obj/010.jpg
#   inflating: /content/data/obj/010.txt
#   inflating: /content/data/obj/011.jpg
# ...

# %%
# Altere o yaml para os dados correspondentes ao seu numero de classes desejado

# %%
# Step 6: Prepare the Dataset Configuration File (talvez seja importante separar as imagens de treino e validação para que os resultados sejam diferentes)
# Example `data.yaml` file for a 5-class custom dataset
with open('data.yaml', 'w') as f:
    f.write('''
train: /content/data/obj
val: /content/gdrive/MyDrive/yolov3/validation
nc: 5
names: ["toolbox", "robot", "cone", "person", "youbot"]
''')

# %%
# Step 7: Train the Model
# !python train.py --data data.yaml --cfg /content/yolov3/models/yolov3-tiny.yaml --weights yolov3.pt --epochs 10000 --batch-size 16 --img-size 416 --project /content/gdrive/MyDrive/yolov3 --name results
# Out:
# ^C

# %%
# Alternative trainning: Keep trainning from the last saved Weights

# !python /content/yolov3/train.py --data /content/yolov3/data.yaml --cfg /content/yolov3/models/yolov3-tiny.yaml --weights /content/gdrive/MyDrive/yolov3/results/weights/last.pt --epochs 200 --batch-size 16 --img-size 416 --project /content/gdrive/MyDrive/yolov3 --name results --patience 0
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-02-04 21:44:50.925191: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738705490.974027    4014 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738705490.987132    4014 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...
